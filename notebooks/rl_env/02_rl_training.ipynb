# %% [markdown]
# # 02 – RL Agent Training (Fair PPO + CNN)
#
# Human-fair training: `PacmanGridEnv` obserwacja `9×31×28` (ściany, kropki, duchy, owoc, życia HUD, **poziom**),
# **bez action masks** i **bez PBRS**. Algorytm **PPO** z siecią `PacmanCNN`, curriculum 2-fazowy.
#
# Headless: `python scripts/train_ppo_fair.py --fresh-start`
#
# Logowanie tekstowe co `LOG_EVERY` kroków + metryki PPO loss do MLflow. Eval na seedach 100–103 co `EVAL_EVERY`.
# Wykresy: `python scripts/plot_training.py` → `reports/training_dashboard.png`, `training_loss_dashboard.png`.
#
# Naciśnij **Stop**, aby przerwać; checkpoint zapisywany co `CHECKPOINT_EVERY` kroków.

# %%
# Install sb3-contrib into THIS kernel (idempotent; %pip ensures correct interpreter).
import importlib, subprocess, sys
if importlib.util.find_spec("sb3_contrib") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "--quiet", "sb3-contrib"])
    print("sb3-contrib installed — restart NOT required, just re-run the next cell.")
else:
    print("sb3-contrib already available.")
# Out:
# sb3-contrib already available.

# %%
import sys, os, shutil
sys.path.insert(0, '../..')

import torch
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv, VecMonitor, VecFrameStack

from src.environment.pacman_env import PacmanGridEnv
from src.utils.lr_schedule import constant_schedule, linear_schedule
from src.utils.maskable_env import (
    create_maskable_ppo, load_trainable_model, wrap_with_action_masker, predict_action,
)
from src.utils.mlflow_logger import MLflowLogger
from src.utils.ppo_cnn import policy_kwargs
from src.utils.training_callbacks import ConsoleCallback
from src.utils.obs_sync import obs_channel_config_from_checkpoint, peek_checkpoint, validate_model_env

_EPISODE_INFO_KEYS = (
    'score', 'level', 'pellet_completion',
    'episode_deaths', 'max_level_reached', 'level_clears',
)

# %%
# ── Configuration ────────────────────────────────────────────────────────────
N_ENVS            = 8
N_STEPS           = 512
N_STACK           = 4
PHASE1_STEPS      = 1_000_000
PHASE2_STEPS      = 4_000_000
ADDITIONAL_STEPS  = 2_000_000   # resume: train THIS MANY MORE steps
CHECKPOINT_PATH   = os.path.join('../..', 'models', 'ppo_pacman')
CHECKPOINT_EVERY  = 100_000
LOG_EVERY         = 10_000
EVAL_EVERY        = 100_000
FRESH_START       = False
USE_MASKABLE      = True        # MaskablePPO + action masks (recommended)
LR_SCHEDULE       = 'constant'  # avoids LR→0 on long resume segments
LEARNING_RATE     = 1e-4
ENT_COEF_PHASE1   = 0.02
ENT_COEF_PHASE2   = 0.02
ENT_COEF_PLATEAU  = 0.03
TB_LOG            = os.path.join('../..', 'logs', 'tensorboard')

# Penalty constants — keep in sync with scripts/train_ppo_fair.py
NEAR_MISS_PENALTY         = -12.0
LATE_ENDGAME_FAIL_PENALTY = -4.0

INCLUDE_COMPLETION_PLANE = FRESH_START
INCLUDE_FRIGHTENED_PLANE = FRESH_START
INCLUDE_DERIVED_PLANES = FRESH_START
EASY_ENDGAME = FRESH_START

def make_env(seed: int, max_steps: int):
    def _f():
        env = PacmanGridEnv(
            seed=seed, max_steps=max_steps,
            step_penalty=-0.0005, reward_scale_div=50.0,
            death_penalty=-3.0, level_bonus=5000.0,
            endgame_death_surcharge=-3.0,
            idle_penalty=-0.02, wasted_power_penalty=-1.5,
            near_miss_penalty=NEAR_MISS_PENALTY,
            late_endgame_fail_penalty=LATE_ENDGAME_FAIL_PENALTY,
            enable_milestones=True,
            pbrs_coef=0.0, human_fair=True,
            include_completion_plane=INCLUDE_COMPLETION_PLANE,
            include_frightened_plane=INCLUDE_FRIGHTENED_PLANE,
            include_derived_planes=INCLUDE_DERIVED_PLANES,
            easy_endgame=EASY_ENDGAME,
        )
        if USE_MASKABLE:
            env = wrap_with_action_masker(env)
        return Monitor(env, info_keywords=_EPISODE_INFO_KEYS)
    return _f

def build_vec(max_steps: int):
    fns = [make_env(seed=i, max_steps=max_steps) for i in range(N_ENVS)]
    v = DummyVecEnv(fns) if os.name == 'nt' else SubprocVecEnv(fns)
    v = VecMonitor(v)
    return VecFrameStack(v, n_stack=N_STACK, channels_order='first')

_lr_fn = constant_schedule(LEARNING_RATE) if LR_SCHEDULE == 'constant' else linear_schedule(LEARNING_RATE)

models_dir = os.path.join('../..', 'models')
checkpoint_zip = CHECKPOINT_PATH + '.zip'
if FRESH_START and os.path.isdir(models_dir):
    removed = 0
    for root, _, files in os.walk(models_dir):
        for f in files:
            if f.endswith('.zip'):
                os.remove(os.path.join(root, f))
                removed += 1
    print(f'[Fresh start] removed {removed} checkpoint(s)')

resuming = os.path.exists(checkpoint_zip) and not FRESH_START
model = None

if resuming:
    INCLUDE_COMPLETION_PLANE, INCLUDE_FRIGHTENED_PLANE, INCLUDE_DERIVED_PLANES = obs_channel_config_from_checkpoint(
        checkpoint_zip, N_STACK
    )
    EASY_ENDGAME = False
    peek = peek_checkpoint(CHECKPOINT_PATH, device='auto')
    start_steps = int(peek.num_timesteps)
    del peek
    max_steps_env = 16000 if start_steps >= PHASE1_STEPS else 5000
    target_timesteps = start_steps + ADDITIONAL_STEPS
    vec_env = build_vec(max_steps_env)
    model = load_trainable_model(
        CHECKPOINT_PATH, vec_env, use_maskable=USE_MASKABLE, device='auto',
        create_kwargs=dict(
            learning_rate=_lr_fn, n_steps=N_STEPS, batch_size=512,
            ent_coef=ENT_COEF_PHASE1, device='auto', tensorboard_log=TB_LOG,
        ),
    )
    print(
        f'[Resume] checkpoint @ {start_steps:,} | maskable={USE_MASKABLE} | '
        f'completion={INCLUDE_COMPLETION_PLANE} frightened={INCLUDE_FRIGHTENED_PLANE} derived={INCLUDE_DERIVED_PLANES}'
    )
else:
    start_steps = 0
    max_steps_env = 5000
    target_timesteps = PHASE1_STEPS + PHASE2_STEPS
    ch = 9 + int(INCLUDE_COMPLETION_PLANE) + int(INCLUDE_FRIGHTENED_PLANE) + (6 if INCLUDE_DERIVED_PLANES else 0)
    algo = 'MaskablePPO' if USE_MASKABLE else 'PPO'
    print(f'[Initial run] {algo} + PacmanCNN ({ch}ch × stack {N_STACK})')

vec_env = build_vec(max_steps_env)

if model is None:
    if USE_MASKABLE:
        model = create_maskable_ppo(
            vec_env, learning_rate=_lr_fn, n_steps=N_STEPS, batch_size=512,
            ent_coef=ENT_COEF_PHASE1, device='auto', tensorboard_log=TB_LOG,
        )
    else:
        model = PPO(
            'CnnPolicy', vec_env, learning_rate=_lr_fn, n_steps=N_STEPS,
            batch_size=512, n_epochs=4, gamma=0.995, gae_lambda=0.95,
            clip_range=0.2, ent_coef=ENT_COEF_PHASE1,
            vf_coef=0.5, max_grad_norm=0.5,
            policy_kwargs=policy_kwargs(), verbose=0, device='auto',
            tensorboard_log=TB_LOG,
        )
else:
    model.set_env(vec_env)
    model.ent_coef = max(ENT_COEF_PHASE2, float(model.ent_coef))

validate_model_env(model, vec_env, context='notebook cell 4')
print(f'Obs: {vec_env.observation_space.shape} | model: {model.observation_space.shape} | target={target_timesteps:,}')
# Out:
# [Resume] checkpoint @ 3,404,864 | maskable=True | completion=True frightened=True
# /home/mwrona/PAC-MAN-AI/.venv/lib64/python3.14/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:43: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# Obs: (44, 31, 28) | model: (44, 31, 28) | target=5,404,864

# %% [markdown]
# ## Training loop (2-phase curriculum)
#
# Phase 1: `max_steps=5000`, `ent_coef=0.02`. Phase 2: multi-level, `max_steps=16000`, `ent_coef=0.02`.
# Reward = Δscore/50 − 3·death − 0.0005/krok (+5000 za level clear). LR constant 1e-4.
# Penalties: near_miss=−12, late_endgame_fail=−4.
# Held-out eval (seeds 100–103) co `EVAL_EVERY` kroków.

# %%
print(f'Training — MaskablePPO={USE_MASKABLE} | resume_from={start_steps:,} | target={target_timesteps:,}\n')

with MLflowLogger(experiment_name='rl_training', run_name='ppo_fair_cnn') as logger:
    logger.log_params({
        'algorithm': 'MaskablePPO' if USE_MASKABLE else 'PPO',
        'n_envs': N_ENVS, 'n_stack': N_STACK, 'resume_from': start_steps,
        'target_timesteps': target_timesteps, 'gamma': 0.995,
        'learning_rate': LEARNING_RATE, 'lr_schedule': LR_SCHEDULE,
        'ent_coef_phase1': ENT_COEF_PHASE1, 'ent_coef_phase2': ENT_COEF_PHASE2,
        'ent_coef_plateau': ENT_COEF_PLATEAU,
        'ent_plateau_pellet_threshold': 0.75,
        'near_miss_penalty': NEAR_MISS_PENALTY,
        'late_endgame_fail_penalty': LATE_ENDGAME_FAIL_PENALTY,
        'include_completion_plane': INCLUDE_COMPLETION_PLANE,
        'include_frightened_plane': INCLUDE_FRIGHTENED_PLANE,
        'action_masks': USE_MASKABLE, 'eval_every': EVAL_EVERY,
    })

    callback = ConsoleCallback(
        CHECKPOINT_PATH, CHECKPOINT_EVERY, LOG_EVERY, logger,
        target_timesteps=target_timesteps, resume_from=start_steps,
        eval_every=EVAL_EVERY, n_stack=N_STACK,
        include_completion_plane=INCLUDE_COMPLETION_PLANE,
        include_frightened_plane=INCLUDE_FRIGHTENED_PLANE,
        near_miss_penalty=NEAR_MISS_PENALTY,
        late_endgame_fail_penalty=LATE_ENDGAME_FAIL_PENALTY,
        ent_coef_plateau=ENT_COEF_PLATEAU,
        ent_coef_normal=ENT_COEF_PHASE2,
        use_action_masks=USE_MASKABLE,
    )

    run_phase1 = (not resuming) and (PHASE1_STEPS > 0) and (model.num_timesteps < PHASE1_STEPS)

    if run_phase1:
        validate_model_env(model, model.get_env(), context='before phase 1 learn')
        try:
            print(f'=== Phase 1 -> {PHASE1_STEPS:,} steps ===')
            model.learn(total_timesteps=PHASE1_STEPS, callback=callback,
                        reset_num_timesteps=True, progress_bar=False)
        except KeyboardInterrupt:
            print('\nPhase 1 interrupted.')
        vec_env.close()
        vec_env2 = build_vec(max_steps=16000)
        validate_model_env(model, vec_env2, context='before phase 2 set_env')
        model.set_env(vec_env2)
        model.ent_coef = ENT_COEF_PHASE2

    try:
        remaining = max(0, target_timesteps - int(model.num_timesteps))
        print(f'\n=== Training until {target_timesteps:,} steps (+{remaining:,} remaining) ===')
        if remaining > 0:
            model.learn(total_timesteps=remaining, callback=callback,
                        reset_num_timesteps=False, progress_bar=False)
    except KeyboardInterrupt:
        print('\nTraining interrupted.')
    finally:
        model.save(CHECKPOINT_PATH)
        logger.log_metrics({'total_timesteps': model.num_timesteps})
        training_history = callback.history()
        print(f'\nSaved -> {CHECKPOINT_PATH}.zip @ {model.num_timesteps:,} steps')
# Out:
# Training — MaskablePPO=True | resume_from=3,404,864 | target=5,404,864
#
#
# === Training until 5,404,864 steps (+2,000,000 remaining) ===
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,410,000 / 5,404,864  |    0.1 min  |   2602 fps
# --------------------------------------------------------------
#   Episodes (50):  return   68.85  |  score    4151  (scaled  83.0)  |  gap -14.18
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.3%
#   Survival:       length   378  |  deaths/ep 3.00  |  total eps 9
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=10.8706  |  value_loss=24.6921  |  entropy_loss=-0.3834
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,420,000 / 5,404,864  |    0.2 min  |   1437 fps
# --------------------------------------------------------------
#   Episodes (50):  return   89.66  |  score    5219  (scaled 104.4)  |  gap -14.71
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  69.8%
#   Survival:       length   388  |  deaths/ep 3.00  |  total eps 35
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.1059  |  value_loss=12.6326  |  entropy_loss=-0.3727
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,430,000 / 5,404,864  |    0.3 min  |   1510 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.01  |  score    5222  (scaled 104.4)  |  gap -14.44
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  69.8%
#   Survival:       length   406  |  deaths/ep 3.00  |  total eps 58
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=8.4949  |  value_loss=21.2790  |  entropy_loss=-0.3655
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,440,000 / 5,404,864  |    0.4 min  |   1520 fps
# --------------------------------------------------------------
#   Episodes (50):  return   82.80  |  score    4862  (scaled  97.2)  |  gap -14.44
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.2%
#   Survival:       length   411  |  deaths/ep 3.02  |  total eps 84
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.8880  |  value_loss=12.3888  |  entropy_loss=-0.3857
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,450,000 / 5,404,864  |    0.5 min  |   1519 fps
# --------------------------------------------------------------
#   Episodes (50):  return   89.36  |  score    5199  (scaled 104.0)  |  gap -14.62
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  71.2%
#   Survival:       length   423  |  deaths/ep 3.02  |  total eps 105
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.8263  |  value_loss=5.9823  |  entropy_loss=-0.3746
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,460,000 / 5,404,864  |    0.6 min  |   1735 fps
# --------------------------------------------------------------
#   Episodes (50):  return   92.19  |  score    5345  (scaled 106.9)  |  gap -14.70
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  76.2%
#   Survival:       length   436  |  deaths/ep 3.00  |  total eps 128
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.6195  |  value_loss=9.2972  |  entropy_loss=-0.3316
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,470,000 / 5,404,864  |    0.7 min  |   1565 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.34  |  score    5307  (scaled 106.1)  |  gap -14.81
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  76.2%
#   Survival:       length   430  |  deaths/ep 3.02  |  total eps 153
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.9794  |  value_loss=13.1165  |  entropy_loss=-0.3501
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,480,000 / 5,404,864  |    0.8 min  |   1518 fps
# --------------------------------------------------------------
#   Episodes (50):  return   88.66  |  score    5181  (scaled 103.6)  |  gap -14.97
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  73.0%
#   Survival:       length   428  |  deaths/ep 3.02  |  total eps 176
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=10.5576  |  value_loss=26.9709  |  entropy_loss=-0.4013
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,490,000 / 5,404,864  |    0.9 min  |   1514 fps
# --------------------------------------------------------------
#   Episodes (50):  return   76.51  |  score    4585  (scaled  91.7)  |  gap -15.19
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.2%
#   Survival:       length   418  |  deaths/ep 3.00  |  total eps 197
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.5014  |  value_loss=6.9780  |  entropy_loss=-0.4444
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,500,000 / 5,404,864  |    1.0 min  |   1488 fps
# --------------------------------------------------------------
#   Episodes (50):  return   71.03  |  score    4330  (scaled  86.6)  |  gap -15.57
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.5%
#   Survival:       length   446  |  deaths/ep 3.00  |  total eps 220
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.2416  |  value_loss=12.4117  |  entropy_loss=-0.4329
# --------------------------------------------------------------
#
#   [eval @ 3,500,000] score=5492  return=91.9  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 3,500,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,510,000 / 5,404,864  |    1.2 min  |   1117 fps
# --------------------------------------------------------------
#   Episodes (50):  return   75.95  |  score    4576  (scaled  91.5)  |  gap -15.57
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.3%
#   Survival:       length   447  |  deaths/ep 3.00  |  total eps 242
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.3930  |  value_loss=7.6821  |  entropy_loss=-0.3948
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,520,000 / 5,404,864  |    1.3 min  |   1466 fps
# --------------------------------------------------------------
#   Episodes (50):  return   87.32  |  score    5127  (scaled 102.5)  |  gap -15.21
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.2%
#   Survival:       length   431  |  deaths/ep 3.00  |  total eps 266
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=7.3904  |  value_loss=16.8765  |  entropy_loss=-0.4443
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,530,000 / 5,404,864  |    1.4 min  |   1458 fps
# --------------------------------------------------------------
#   Episodes (50):  return   88.30  |  score    5148  (scaled 103.0)  |  gap -14.66
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.6%
#   Survival:       length   417  |  deaths/ep 3.00  |  total eps 289
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=13.6750  |  value_loss=36.3280  |  entropy_loss=-0.4165
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,540,000 / 5,404,864  |    1.5 min  |   1596 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.65  |  score    5484  (scaled 109.7)  |  gap -15.03
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.1%
#   Survival:       length   449  |  deaths/ep 3.04  |  total eps 308
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.3870  |  value_loss=12.7150  |  entropy_loss=-0.5185
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,550,000 / 5,404,864  |    1.6 min  |   1389 fps
# --------------------------------------------------------------
#   Episodes (50):  return   96.03  |  score    5552  (scaled 111.0)  |  gap -15.02
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.5%
#   Survival:       length   449  |  deaths/ep 3.06  |  total eps 324
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.1060  |  value_loss=8.7645  |  entropy_loss=-0.5241
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,560,000 / 5,404,864  |    1.8 min  |   1427 fps
# --------------------------------------------------------------
#   Episodes (50):  return   97.86  |  score    5645  (scaled 112.9)  |  gap -15.05
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.8%
#   Survival:       length   463  |  deaths/ep 3.06  |  total eps 341
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=15.1598  |  value_loss=37.9413  |  entropy_loss=-0.4843
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,570,000 / 5,404,864  |    1.9 min  |   1414 fps
# --------------------------------------------------------------
#   Episodes (50):  return   92.98  |  score    5359  (scaled 107.2)  |  gap -14.20
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  64.8%
#   Survival:       length   576  |  deaths/ep 3.04  |  total eps 363
#   Shaping:        milestone_r  0.06  |  ent_coef 0.0300
#   PPO loss:       loss=5.8967  |  value_loss=15.5609  |  entropy_loss=-0.3944
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,580,000 / 5,404,864  |    2.0 min  |   1412 fps
# --------------------------------------------------------------
#   Episodes (50):  return   81.49  |  score    4765  (scaled  95.3)  |  gap -13.80
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.4%
#   Survival:       length   576  |  deaths/ep 3.02  |  total eps 387
#   Shaping:        milestone_r  0.06  |  ent_coef 0.0300
#   PPO loss:       loss=12.9705  |  value_loss=44.6961  |  entropy_loss=-0.4074
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,590,000 / 5,404,864  |    2.1 min  |   1371 fps
# --------------------------------------------------------------
#   Episodes (50):  return   70.31  |  score    4194  (scaled  83.9)  |  gap -13.57
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  65.2%
#   Survival:       length   419  |  deaths/ep 3.00  |  total eps 408
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=11.7060  |  value_loss=25.4418  |  entropy_loss=-0.4889
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,600,000 / 5,404,864  |    2.2 min  |   1369 fps
# --------------------------------------------------------------
#   Episodes (50):  return   72.50  |  score    4317  (scaled  86.3)  |  gap -13.84
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  63.9%
#   Survival:       length   405  |  deaths/ep 3.00  |  total eps 429
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.7666  |  value_loss=5.8674  |  entropy_loss=-0.5418
# --------------------------------------------------------------
#
#   [eval @ 3,600,000] score=6405  return=113.3  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 3,600,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,610,000 / 5,404,864  |    2.4 min  |   1033 fps
# --------------------------------------------------------------
#   Episodes (50):  return   77.23  |  score    4559  (scaled  91.2)  |  gap -13.94
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  63.2%
#   Survival:       length   397  |  deaths/ep 3.00  |  total eps 447
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.5650  |  value_loss=13.2832  |  entropy_loss=-0.4349
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,620,000 / 5,404,864  |    2.5 min  |   1389 fps
# --------------------------------------------------------------
#   Episodes (50):  return   83.79  |  score    4887  (scaled  97.7)  |  gap -13.95
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  61.7%
#   Survival:       length   382  |  deaths/ep 3.02  |  total eps 467
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.6509  |  value_loss=6.4435  |  entropy_loss=-0.5444
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,630,000 / 5,404,864  |    2.6 min  |   1496 fps
# --------------------------------------------------------------
#   Episodes (50):  return   82.94  |  score    4849  (scaled  97.0)  |  gap -14.03
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  63.4%
#   Survival:       length   401  |  deaths/ep 3.02  |  total eps 483
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.4864  |  value_loss=15.0221  |  entropy_loss=-0.5205
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,640,000 / 5,404,864  |    2.8 min  |   1373 fps
# --------------------------------------------------------------
#   Episodes (50):  return   68.80  |  score    4139  (scaled  82.8)  |  gap -13.97
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  62.5%
#   Survival:       length   411  |  deaths/ep 3.00  |  total eps 503
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.3801  |  value_loss=7.6717  |  entropy_loss=-0.5029
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,650,000 / 5,404,864  |    2.9 min  |   1352 fps
# --------------------------------------------------------------
#   Episodes (50):  return   68.75  |  score    4175  (scaled  83.5)  |  gap -14.75
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  67.6%
#   Survival:       length   583  |  deaths/ep 3.02  |  total eps 519
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=7.4287  |  value_loss=19.2083  |  entropy_loss=-0.4092
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,660,000 / 5,404,864  |    3.0 min  |   1362 fps
# --------------------------------------------------------------
#   Episodes (50):  return   79.51  |  score    4734  (scaled  94.7)  |  gap -15.16
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.0%
#   Survival:       length   580  |  deaths/ep 3.02  |  total eps 538
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.3328  |  value_loss=16.9661  |  entropy_loss=-0.4026
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,670,000 / 5,404,864  |    3.1 min  |   1324 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.65  |  score    5335  (scaled 106.7)  |  gap -15.04
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.1%
#   Survival:       length   445  |  deaths/ep 3.02  |  total eps 560
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.8757  |  value_loss=9.0288  |  entropy_loss=-0.4308
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,680,000 / 5,404,864  |    3.3 min  |   1333 fps
# --------------------------------------------------------------
#   Episodes (50):  return   83.05  |  score    4894  (scaled  97.9)  |  gap -14.83
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  69.0%
#   Survival:       length   435  |  deaths/ep 3.02  |  total eps 579
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.1448  |  value_loss=5.9985  |  entropy_loss=-0.4863
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,690,000 / 5,404,864  |    3.4 min  |   1350 fps
# --------------------------------------------------------------
#   Episodes (50):  return   78.90  |  score    4665  (scaled  93.3)  |  gap -14.41
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  65.8%
#   Survival:       length   424  |  deaths/ep 3.02  |  total eps 603
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.8993  |  value_loss=6.6258  |  entropy_loss=-0.4171
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,700,000 / 5,404,864  |    3.5 min  |   1337 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.88  |  score    5354  (scaled 107.1)  |  gap -15.19
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.1%
#   Survival:       length   704  |  deaths/ep 3.04  |  total eps 623
#   Shaping:        milestone_r  0.06  |  ent_coef 0.0300
#   PPO loss:       loss=16.6641  |  value_loss=46.1320  |  entropy_loss=-0.3198
# --------------------------------------------------------------
#
#   [eval @ 3,700,000] score=5105  return=87.2  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 3,700,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,710,000 / 5,404,864  |    3.8 min  |    499 fps
# --------------------------------------------------------------
#   Episodes (50):  return   95.06  |  score    5526  (scaled 110.5)  |  gap -15.47
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  69.8%
#   Survival:       length   701  |  deaths/ep 3.04  |  total eps 646
#   Shaping:        milestone_r  0.06  |  ent_coef 0.0300
#   PPO loss:       loss=8.0432  |  value_loss=16.9210  |  entropy_loss=-0.4006
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,720,000 / 5,404,864  |    4.0 min  |   1335 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.82  |  score    5493  (scaled 109.9)  |  gap -15.04
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.5%
#   Survival:       length   432  |  deaths/ep 3.06  |  total eps 668
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.9311  |  value_loss=8.6036  |  entropy_loss=-0.4787
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,730,000 / 5,404,864  |    4.1 min  |   1344 fps
# --------------------------------------------------------------
#   Episodes (50):  return   88.96  |  score    5170  (scaled 103.4)  |  gap -14.44
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  61.5%
#   Survival:       length   419  |  deaths/ep 3.04  |  total eps 694
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.6384  |  value_loss=15.7640  |  entropy_loss=-0.4069
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,740,000 / 5,404,864  |    4.2 min  |   1335 fps
# --------------------------------------------------------------
#   Episodes (50):  return   85.30  |  score    4954  (scaled  99.1)  |  gap -13.77
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  58.7%
#   Survival:       length   406  |  deaths/ep 3.02  |  total eps 719
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.7433  |  value_loss=5.1009  |  entropy_loss=-0.4368
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,750,000 / 5,404,864  |    4.3 min  |   1330 fps
# --------------------------------------------------------------
#   Episodes (50):  return   87.79  |  score    5081  (scaled 101.6)  |  gap -13.83
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  60.7%
#   Survival:       length   428  |  deaths/ep 3.04  |  total eps 740
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=9.3271  |  value_loss=20.5412  |  entropy_loss=-0.4083
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,760,000 / 5,404,864  |    4.5 min  |   1318 fps
# --------------------------------------------------------------
#   Episodes (50):  return   92.83  |  score    5338  (scaled 106.8)  |  gap -13.93
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  61.4%
#   Survival:       length   454  |  deaths/ep 3.04  |  total eps 764
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.9701  |  value_loss=7.9629  |  entropy_loss=-0.5027
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,770,000 / 5,404,864  |    4.6 min  |   1304 fps
# --------------------------------------------------------------
#   Episodes (50):  return   89.60  |  score    5166  (scaled 103.3)  |  gap -13.71
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  59.0%
#   Survival:       length   432  |  deaths/ep 3.02  |  total eps 784
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=10.1389  |  value_loss=20.4737  |  entropy_loss=-0.4630
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,780,000 / 5,404,864  |    4.7 min  |   1314 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.71  |  score    5438  (scaled 108.8)  |  gap -14.05
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  62.6%
#   Survival:       length   443  |  deaths/ep 3.04  |  total eps 807
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.3437  |  value_loss=12.3599  |  entropy_loss=-0.4411
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,790,000 / 5,404,864  |    4.8 min  |   1276 fps
# --------------------------------------------------------------
#   Episodes (50):  return   93.97  |  score    5403  (scaled 108.1)  |  gap -14.09
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  64.2%
#   Survival:       length   417  |  deaths/ep 3.02  |  total eps 828
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=8.1458  |  value_loss=18.5353  |  entropy_loss=-0.4103
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,800,000 / 5,404,864  |    5.0 min  |   1388 fps
# --------------------------------------------------------------
#   Episodes (50):  return   87.92  |  score    5111  (scaled 102.2)  |  gap -14.30
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  64.8%
#   Survival:       length   410  |  deaths/ep 3.02  |  total eps 847
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.9608  |  value_loss=14.9063  |  entropy_loss=-0.4171
# --------------------------------------------------------------
#
#   [eval @ 3,800,000] score=5058  return=86.7  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 3,800,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,810,000 / 5,404,864  |    5.1 min  |    997 fps
# --------------------------------------------------------------
#   Episodes (50):  return   77.90  |  score    4635  (scaled  92.7)  |  gap -14.80
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  67.0%
#   Survival:       length   424  |  deaths/ep 3.02  |  total eps 868
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=9.3132  |  value_loss=24.9898  |  entropy_loss=-0.4105
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,820,000 / 5,404,864  |    5.3 min  |   1277 fps
# --------------------------------------------------------------
#   Episodes (50):  return   83.92  |  score    4955  (scaled  99.1)  |  gap -15.17
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.8%
#   Survival:       length   437  |  deaths/ep 3.04  |  total eps 890
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.7386  |  value_loss=14.8391  |  entropy_loss=-0.3983
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,830,000 / 5,404,864  |    5.4 min  |   1308 fps
# --------------------------------------------------------------
#   Episodes (50):  return   89.75  |  score    5230  (scaled 104.6)  |  gap -14.84
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.9%
#   Survival:       length   416  |  deaths/ep 3.04  |  total eps 911
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=13.6424  |  value_loss=34.9179  |  entropy_loss=-0.3858
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,840,000 / 5,404,864  |    5.5 min  |   1295 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.44  |  score    5237  (scaled 104.7)  |  gap -14.29
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.8%
#   Survival:       length   416  |  deaths/ep 3.00  |  total eps 930
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.2470  |  value_loss=24.0174  |  entropy_loss=-0.4083
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,850,000 / 5,404,864  |    5.6 min  |   1294 fps
# --------------------------------------------------------------
#   Episodes (50):  return   81.12  |  score    4793  (scaled  95.9)  |  gap -14.73
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  69.6%
#   Survival:       length   623  |  deaths/ep 3.00  |  total eps 951
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.9835  |  value_loss=15.9390  |  entropy_loss=-0.3925
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,860,000 / 5,404,864  |    5.8 min  |   1259 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.36  |  score    5326  (scaled 106.5)  |  gap -15.15
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.0%
#   Survival:       length   648  |  deaths/ep 3.02  |  total eps 975
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.8828  |  value_loss=18.0735  |  entropy_loss=-0.4713
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,870,000 / 5,404,864  |    5.9 min  |   1306 fps
# --------------------------------------------------------------
#   Episodes (50):  return   93.32  |  score    5436  (scaled 108.7)  |  gap -15.41
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  71.2%
#   Survival:       length   449  |  deaths/ep 3.02  |  total eps 998
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.7215  |  value_loss=19.7138  |  entropy_loss=-0.4401
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,880,000 / 5,404,864  |    6.0 min  |   1346 fps
# --------------------------------------------------------------
#   Episodes (50):  return   85.18  |  score    5013  (scaled 100.3)  |  gap -15.09
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.1%
#   Survival:       length   447  |  deaths/ep 3.00  |  total eps 1020
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=8.4082  |  value_loss=15.4984  |  entropy_loss=-0.4108
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,890,000 / 5,404,864  |    6.2 min  |   1290 fps
# --------------------------------------------------------------
#   Episodes (50):  return   85.18  |  score    4999  (scaled 100.0)  |  gap -14.80
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.5%
#   Survival:       length   453  |  deaths/ep 3.00  |  total eps 1041
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.4124  |  value_loss=6.6759  |  entropy_loss=-0.4710
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,900,000 / 5,404,864  |    6.3 min  |   1267 fps
# --------------------------------------------------------------
#   Episodes (50):  return   83.26  |  score    4895  (scaled  97.9)  |  gap -14.65
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.9%
#   Survival:       length   475  |  deaths/ep 3.00  |  total eps 1057
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.1771  |  value_loss=4.1222  |  entropy_loss=-0.5090
# --------------------------------------------------------------
#
#   [eval @ 3,900,000] score=5888  return=102.2  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 3,900,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,910,000 / 5,404,864  |    6.7 min  |    453 fps
# --------------------------------------------------------------
#   Episodes (50):  return   78.39  |  score    4653  (scaled  93.1)  |  gap -14.67
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.8%
#   Survival:       length   473  |  deaths/ep 3.00  |  total eps 1077
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.3333  |  value_loss=4.6581  |  entropy_loss=-0.5033
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,920,000 / 5,404,864  |    6.8 min  |   1285 fps
# --------------------------------------------------------------
#   Episodes (50):  return   76.27  |  score    4540  (scaled  90.8)  |  gap -14.53
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  65.7%
#   Survival:       length   465  |  deaths/ep 3.00  |  total eps 1095
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.4028  |  value_loss=5.4760  |  entropy_loss=-0.4780
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,930,000 / 5,404,864  |    6.9 min  |   1302 fps
# --------------------------------------------------------------
#   Episodes (50):  return   85.61  |  score    5025  (scaled 100.5)  |  gap -14.90
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.4%
#   Survival:       length   474  |  deaths/ep 3.02  |  total eps 1111
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.8659  |  value_loss=6.0414  |  entropy_loss=-0.4846
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,940,000 / 5,404,864  |    7.1 min  |   1245 fps
# --------------------------------------------------------------
#   Episodes (50):  return   88.41  |  score    5172  (scaled 103.4)  |  gap -15.04
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.8%
#   Survival:       length   468  |  deaths/ep 3.02  |  total eps 1129
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.7994  |  value_loss=9.3685  |  entropy_loss=-0.4550
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,950,000 / 5,404,864  |    7.2 min  |   1272 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.53  |  score    5334  (scaled 106.7)  |  gap -15.14
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.6%
#   Survival:       length   686  |  deaths/ep 3.02  |  total eps 1148
#   Shaping:        milestone_r  0.18  |  ent_coef 0.0300
#   PPO loss:       loss=11.1787  |  value_loss=28.2817  |  entropy_loss=-0.3828
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,960,000 / 5,404,864  |    7.3 min  |   1271 fps
# --------------------------------------------------------------
#   Episodes (50):  return   95.58  |  score    5523  (scaled 110.5)  |  gap -14.89
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.8%
#   Survival:       length   679  |  deaths/ep 3.00  |  total eps 1166
#   Shaping:        milestone_r  0.18  |  ent_coef 0.0300
#   PPO loss:       loss=5.7077  |  value_loss=17.7339  |  entropy_loss=-0.4150
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,970,000 / 5,404,864  |    7.4 min  |   1373 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.16  |  score    5206  (scaled 104.1)  |  gap -13.96
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.4%
#   Survival:       length   519  |  deaths/ep 3.00  |  total eps 1190
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.7846  |  value_loss=8.7269  |  entropy_loss=-0.4362
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,980,000 / 5,404,864  |    7.6 min  |   1251 fps
# --------------------------------------------------------------
#   Episodes (50):  return   87.80  |  score    5067  (scaled 101.3)  |  gap -13.55
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  63.4%
#   Survival:       length   444  |  deaths/ep 3.00  |  total eps 1211
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.5705  |  value_loss=12.2306  |  entropy_loss=-0.4397
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  3,990,000 / 5,404,864  |    7.7 min  |   1256 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.30  |  score    5246  (scaled 104.9)  |  gap -13.63
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  64.4%
#   Survival:       length   434  |  deaths/ep 3.00  |  total eps 1228
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=0.9564  |  value_loss=3.3244  |  entropy_loss=-0.4879
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,000,000 / 5,404,864  |    7.8 min  |   1279 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.60  |  score    5238  (scaled 104.8)  |  gap -14.17
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  68.7%
#   Survival:       length   533  |  deaths/ep 3.00  |  total eps 1247
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.4976  |  value_loss=8.3791  |  entropy_loss=-0.3678
# --------------------------------------------------------------
#
#   [eval @ 4,000,000] score=6360  return=113.1  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 4,000,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,010,000 / 5,404,864  |    8.2 min  |    436 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.33  |  score    5454  (scaled 109.1)  |  gap -14.75
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.7%
#   Survival:       length   558  |  deaths/ep 3.00  |  total eps 1266
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.2549  |  value_loss=8.8888  |  entropy_loss=-0.4202
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,020,000 / 5,404,864  |    8.3 min  |   1269 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.35  |  score    5458  (scaled 109.2)  |  gap -14.81
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.4%
#   Survival:       length   535  |  deaths/ep 3.00  |  total eps 1286
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.2533  |  value_loss=11.5491  |  entropy_loss=-0.4632
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,030,000 / 5,404,864  |    8.5 min  |   1295 fps
# --------------------------------------------------------------
#   Episodes (50):  return   83.98  |  score    4929  (scaled  98.6)  |  gap -14.60
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  71.4%
#   Survival:       length   501  |  deaths/ep 3.00  |  total eps 1310
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.7636  |  value_loss=10.5818  |  entropy_loss=-0.4001
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,040,000 / 5,404,864  |    8.6 min  |   1250 fps
# --------------------------------------------------------------
#   Episodes (50):  return   76.15  |  score    4546  (scaled  90.9)  |  gap -14.78
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.9%
#   Survival:       length   481  |  deaths/ep 3.00  |  total eps 1328
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.6325  |  value_loss=7.4428  |  entropy_loss=-0.4262
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,050,000 / 5,404,864  |    8.7 min  |   1279 fps
# --------------------------------------------------------------
#   Episodes (50):  return   76.06  |  score    4552  (scaled  91.0)  |  gap -14.99
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.4%
#   Survival:       length   484  |  deaths/ep 3.00  |  total eps 1348
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.8851  |  value_loss=11.0277  |  entropy_loss=-0.3668
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,060,000 / 5,404,864  |    8.9 min  |   1361 fps
# --------------------------------------------------------------
#   Episodes (50):  return   88.56  |  score    5180  (scaled 103.6)  |  gap -15.03
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  76.0%
#   Survival:       length   488  |  deaths/ep 3.00  |  total eps 1369
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.9598  |  value_loss=9.5833  |  entropy_loss=-0.4033
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,070,000 / 5,404,864  |    9.0 min  |   1225 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.70  |  score    5489  (scaled 109.8)  |  gap -15.07
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.3%
#   Survival:       length   496  |  deaths/ep 3.02  |  total eps 1392
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=14.4452  |  value_loss=33.1701  |  entropy_loss=-0.4186
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,080,000 / 5,404,864  |    9.1 min  |   1246 fps
# --------------------------------------------------------------
#   Episodes (50):  return   94.74  |  score    5461  (scaled 109.2)  |  gap -14.48
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.9%
#   Survival:       length   448  |  deaths/ep 3.02  |  total eps 1415
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=9.1815  |  value_loss=20.7570  |  entropy_loss=-0.4022
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,090,000 / 5,404,864  |    9.3 min  |   1265 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.01  |  score    5193  (scaled 103.9)  |  gap -13.85
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  62.8%
#   Survival:       length   443  |  deaths/ep 3.02  |  total eps 1437
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.5492  |  value_loss=6.8762  |  entropy_loss=-0.5008
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,100,000 / 5,404,864  |    9.4 min  |   1243 fps
# --------------------------------------------------------------
#   Episodes (50):  return   83.82  |  score    4875  (scaled  97.5)  |  gap -13.67
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  63.7%
#   Survival:       length   434  |  deaths/ep 3.00  |  total eps 1462
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=11.4768  |  value_loss=26.4096  |  entropy_loss=-0.4166
# --------------------------------------------------------------
#
#   [eval @ 4,100,000] score=4358  return=71.7  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 4,100,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,110,000 / 5,404,864  |    9.6 min  |    873 fps
# --------------------------------------------------------------
#   Episodes (50):  return   76.10  |  score    4494  (scaled  89.9)  |  gap -13.78
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  64.9%
#   Survival:       length   408  |  deaths/ep 3.02  |  total eps 1485
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.0442  |  value_loss=3.5931  |  entropy_loss=-0.4317
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,120,000 / 5,404,864  |    9.7 min  |   1245 fps
# --------------------------------------------------------------
#   Episodes (50):  return   60.30  |  score    3744  (scaled  74.9)  |  gap -14.57
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.8%
#   Survival:       length   476  |  deaths/ep 3.02  |  total eps 1502
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=0.9243  |  value_loss=3.1992  |  entropy_loss=-0.4084
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,130,000 / 5,404,864  |    9.9 min  |   1258 fps
# --------------------------------------------------------------
#   Episodes (50):  return   43.51  |  score    2930  (scaled  58.6)  |  gap -15.10
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  73.6%
#   Survival:       length   503  |  deaths/ep 3.02  |  total eps 1524
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.0542  |  value_loss=16.0317  |  entropy_loss=-0.3998
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,140,000 / 5,404,864  |   10.0 min  |   1353 fps
# --------------------------------------------------------------
#   Episodes (50):  return   47.21  |  score    3128  (scaled  62.6)  |  gap -15.35
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  76.3%
#   Survival:       length   526  |  deaths/ep 3.00  |  total eps 1542
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=1.9374  |  value_loss=5.9410  |  entropy_loss=-0.3861
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  4,150,000 / 5,404,864  |   10.1 min  |   1231 fps
# --------------------------------------------------------------
# ...
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  75.5%
#   Survival:       length   472  |  deaths/ep 3.02  |  total eps 3648
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.8130  |  value_loss=16.5916  |  entropy_loss=-0.3850
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,170,000 / 5,404,864  |   24.5 min  |   1186 fps
# --------------------------------------------------------------
#   Episodes (50):  return   87.49  |  score    5097  (scaled 101.9)  |  gap -14.45
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.9%
#   Survival:       length   471  |  deaths/ep 3.02  |  total eps 3672
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=7.5649  |  value_loss=24.2885  |  entropy_loss=-0.4090
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,180,000 / 5,404,864  |   24.6 min  |   1207 fps
# --------------------------------------------------------------
#   Episodes (50):  return   91.67  |  score    5319  (scaled 106.4)  |  gap -14.71
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.6%
#   Survival:       length   450  |  deaths/ep 3.02  |  total eps 3693
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=12.8922  |  value_loss=32.6539  |  entropy_loss=-0.3292
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,190,000 / 5,404,864  |   24.8 min  |   1088 fps
# --------------------------------------------------------------
#   Episodes (50):  return  103.26  |  score    5889  (scaled 117.8)  |  gap -14.53
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.1%
#   Survival:       length   442  |  deaths/ep 3.06  |  total eps 3718
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.1416  |  value_loss=10.3204  |  entropy_loss=-0.4085
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,200,000 / 5,404,864  |   24.9 min  |   1128 fps
# --------------------------------------------------------------
#   Episodes (50):  return   95.10  |  score    5478  (scaled 109.6)  |  gap -14.46
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.0%
#   Survival:       length   434  |  deaths/ep 3.04  |  total eps 3739
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=8.4446  |  value_loss=19.4546  |  entropy_loss=-0.4236
# --------------------------------------------------------------
#
#   [eval @ 5,200,000] score=5330  return=90.4  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 5,200,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,210,000 / 5,404,864  |   25.1 min  |    829 fps
# --------------------------------------------------------------
#   Episodes (50):  return   79.71  |  score    4736  (scaled  94.7)  |  gap -15.02
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.7%
#   Survival:       length   469  |  deaths/ep 3.02  |  total eps 3757
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.4612  |  value_loss=7.1720  |  entropy_loss=-0.4250
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,220,000 / 5,404,864  |   25.3 min  |   1174 fps
# --------------------------------------------------------------
#   Episodes (50):  return   80.70  |  score    4790  (scaled  95.8)  |  gap -15.11
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  73.0%
#   Survival:       length   468  |  deaths/ep 3.02  |  total eps 3779
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.1121  |  value_loss=7.4279  |  entropy_loss=-0.3833
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,230,000 / 5,404,864  |   25.4 min  |   1171 fps
# --------------------------------------------------------------
#   Episodes (50):  return   85.50  |  score    4996  (scaled  99.9)  |  gap -14.42
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.1%
#   Survival:       length   438  |  deaths/ep 3.00  |  total eps 3799
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.9552  |  value_loss=14.2995  |  entropy_loss=-0.3976
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,240,000 / 5,404,864  |   25.6 min  |   1138 fps
# --------------------------------------------------------------
#   Episodes (50):  return   87.37  |  score    5029  (scaled 100.6)  |  gap -13.20
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  65.6%
#   Survival:       length   400  |  deaths/ep 3.00  |  total eps 3825
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=5.3613  |  value_loss=11.6592  |  entropy_loss=-0.3976
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,250,000 / 5,404,864  |   25.7 min  |   1254 fps
# --------------------------------------------------------------
#   Episodes (50):  return   82.13  |  score    4774  (scaled  95.5)  |  gap -13.35
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  64.1%
#   Survival:       length   476  |  deaths/ep 3.00  |  total eps 3845
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=12.9461  |  value_loss=52.1425  |  entropy_loss=-0.4548
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,260,000 / 5,404,864  |   25.8 min  |   1192 fps
# --------------------------------------------------------------
#   Episodes (50):  return   98.56  |  score    5650  (scaled 113.0)  |  gap -14.44
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  66.1%
#   Survival:       length   494  |  deaths/ep 3.02  |  total eps 3869
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=8.5479  |  value_loss=23.9831  |  entropy_loss=-0.3766
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,270,000 / 5,404,864  |   26.0 min  |   1250 fps
# --------------------------------------------------------------
#   Episodes (50):  return  106.60  |  score    6085  (scaled 121.7)  |  gap -15.11
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  69.9%
#   Survival:       length   526  |  deaths/ep 3.04  |  total eps 3887
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=6.3014  |  value_loss=17.3850  |  entropy_loss=-0.3918
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,280,000 / 5,404,864  |   26.1 min  |   1262 fps
# --------------------------------------------------------------
#   Episodes (50):  return  103.70  |  score    5951  (scaled 119.0)  |  gap -15.32
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.1%
#   Survival:       length   494  |  deaths/ep 3.04  |  total eps 3906
#   Shaping:        milestone_r  0.24  |  ent_coef 0.0300
#   PPO loss:       loss=6.1865  |  value_loss=20.8398  |  entropy_loss=-0.3978
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,290,000 / 5,404,864  |   26.2 min  |   1322 fps
# --------------------------------------------------------------
#   Episodes (50):  return   97.59  |  score    5658  (scaled 113.2)  |  gap -15.56
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.3%
#   Survival:       length   528  |  deaths/ep 3.02  |  total eps 3926
#   Shaping:        milestone_r  0.24  |  ent_coef 0.0300
#   PPO loss:       loss=4.6108  |  value_loss=10.2398  |  entropy_loss=-0.4710
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,300,000 / 5,404,864  |   26.4 min  |   1252 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.02  |  score    5262  (scaled 105.2)  |  gap -15.21
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.3%
#   Survival:       length   513  |  deaths/ep 3.00  |  total eps 3946
#   Shaping:        milestone_r  0.18  |  ent_coef 0.0300
#   PPO loss:       loss=6.7495  |  value_loss=23.3912  |  entropy_loss=-0.3045
# --------------------------------------------------------------
#
#   [eval @ 5,300,000] score=6282  return=109.3  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 5,300,000 steps
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,310,000 / 5,404,864  |   26.5 min  |    915 fps
# --------------------------------------------------------------
#   Episodes (50):  return   93.67  |  score    5437  (scaled 108.7)  |  gap -15.06
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.2%
#   Survival:       length   500  |  deaths/ep 3.00  |  total eps 3969
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.2898  |  value_loss=8.7542  |  entropy_loss=-0.3469
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,320,000 / 5,404,864  |   26.7 min  |   1273 fps
# --------------------------------------------------------------
#   Episodes (50):  return   93.19  |  score    5420  (scaled 108.4)  |  gap -15.21
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.2%
#   Survival:       length   459  |  deaths/ep 3.00  |  total eps 3992
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=10.9786  |  value_loss=29.9912  |  entropy_loss=-0.3181
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,330,000 / 5,404,864  |   26.8 min  |   1216 fps
# --------------------------------------------------------------
#   Episodes (50):  return   95.85  |  score    5541  (scaled 110.8)  |  gap -14.96
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  73.5%
#   Survival:       length   448  |  deaths/ep 3.02  |  total eps 4012
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=7.3308  |  value_loss=20.6155  |  entropy_loss=-0.4254
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,340,000 / 5,404,864  |   26.9 min  |   1331 fps
# --------------------------------------------------------------
#   Episodes (50):  return   89.19  |  score    5206  (scaled 104.1)  |  gap -14.93
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  71.5%
#   Survival:       length   418  |  deaths/ep 3.04  |  total eps 4034
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=3.2782  |  value_loss=9.5181  |  entropy_loss=-0.4240
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,350,000 / 5,404,864  |   27.1 min  |   1310 fps
# --------------------------------------------------------------
#   Episodes (50):  return   85.85  |  score    5026  (scaled 100.5)  |  gap -14.67
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.8%
#   Survival:       length   431  |  deaths/ep 3.02  |  total eps 4053
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=4.1821  |  value_loss=10.9459  |  entropy_loss=-0.4026
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,360,000 / 5,404,864  |   27.2 min  |   1214 fps
# --------------------------------------------------------------
#   Episodes (50):  return   92.69  |  score    5390  (scaled 107.8)  |  gap -15.10
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  74.3%
#   Survival:       length   442  |  deaths/ep 3.02  |  total eps 4073
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=11.2581  |  value_loss=32.6949  |  entropy_loss=-0.3882
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,370,000 / 5,404,864  |   27.3 min  |   1172 fps
# --------------------------------------------------------------
#   Episodes (50):  return   95.19  |  score    5533  (scaled 110.7)  |  gap -15.47
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  73.1%
#   Survival:       length   517  |  deaths/ep 3.04  |  total eps 4098
#   Shaping:        milestone_r  0.06  |  ent_coef 0.0300
#   PPO loss:       loss=4.9273  |  value_loss=10.4654  |  entropy_loss=-0.4335
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,380,000 / 5,404,864  |   27.5 min  |   1199 fps
# --------------------------------------------------------------
#   Episodes (50):  return   90.74  |  score    5280  (scaled 105.6)  |  gap -14.85
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  72.0%
#   Survival:       length   519  |  deaths/ep 3.04  |  total eps 4121
#   Shaping:        milestone_r  0.06  |  ent_coef 0.0300
#   PPO loss:       loss=3.3068  |  value_loss=9.8238  |  entropy_loss=-0.4104
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,390,000 / 5,404,864  |   27.6 min  |   1230 fps
# --------------------------------------------------------------
#   Episodes (50):  return   86.52  |  score    5044  (scaled 100.9)  |  gap -14.36
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  70.7%
#   Survival:       length   423  |  deaths/ep 3.00  |  total eps 4145
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=8.9913  |  value_loss=28.1019  |  entropy_loss=-0.3395
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#   Pac-Man PPO  |  step  5,400,000 / 5,404,864  |   27.7 min  |   1297 fps
# --------------------------------------------------------------
#   Episodes (50):  return   88.57  |  score    5163  (scaled 103.3)  |  gap -14.69
#   Progress:       level 1.00  |  max_lvl 1.00  |  clears  0.0%  |  pellets  73.3%
#   Survival:       length   440  |  deaths/ep 3.00  |  total eps 4166
#   Shaping:        milestone_r  0.00  |  ent_coef 0.0300
#   PPO loss:       loss=2.7551  |  value_loss=6.8774  |  entropy_loss=-0.3629
# --------------------------------------------------------------
#
#   [eval @ 5,400,000] score=7038  return=123.3  max_lvl=1.00  clear_rate=0%
#
#   [checkpoint] saved -> ../../models/ppo_pacman.zip @ 5,400,000 steps
#
# Saved -> ../../models/ppo_pacman.zip @ 5,405,760 steps

# %% [markdown]
# ## 🎬 Test and Watch the Trained Agent in Action!
#
# Once you believe your agent is trained enough (when its average reward starts climbing and stabilizing), run the cell below to **watch the agent play Pac-Man in real-time** via an ASCII live-render animation!

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output, display
from src.utils.pacman_renderer import render_state_rgb, render_hud_text, ghost_legend_lines
import time

print('Loading trained model...')
checkpoint_zip = CHECKPOINT_PATH + '.zip'
_play_inc_c, _play_inc_f, _play_inc_d = obs_channel_config_from_checkpoint(checkpoint_zip, N_STACK)
raw_env = PacmanGridEnv(
    seed=42, human_fair=True, render_mode='rgb_array',
    include_completion_plane=_play_inc_c,
    include_frightened_plane=_play_inc_f,
    include_derived_planes=_play_inc_d,
)
if USE_MASKABLE:
    raw_env = wrap_with_action_masker(raw_env)
eval_venv = VecFrameStack(
    DummyVecEnv([lambda: Monitor(raw_env)]), n_stack=N_STACK, channels_order='first'
)
trained_model = load_trainable_model(
    CHECKPOINT_PATH, eval_venv, use_maskable=USE_MASKABLE, device='auto',
    create_kwargs=dict(
        learning_rate=1e-4, n_steps=N_STEPS, batch_size=512,
        ent_coef=0.02, device='auto', tensorboard_log=None,
    ),
)
validate_model_env(trained_model, eval_venv, context='play demo')
print(f'Model obs {trained_model.observation_space.shape} | env obs {eval_venv.observation_space.shape}')
obs = eval_venv.reset()
done = False
total_eval_reward = 0.0
step_num = 0

fig, ax = plt.subplots(figsize=(8, 9), facecolor='#111')
plt.close(fig)

def _unwrap_grid(venv):
    e = venv.envs[0]
    while hasattr(e, 'env'):
        e = e.env
    return e

while not done:
    action, _ = predict_action(trained_model, obs, eval_venv, deterministic=True)
    obs, rewards, dones, infos = eval_venv.step(action)
    total_eval_reward += float(rewards[0])
    done = bool(dones[0])
    info = infos[0]
    step_num += 1

    st = _unwrap_grid(eval_venv)._state
    frame = render_state_rgb(st, cell_size=16)
    clear_output(wait=True)

    fig, ax = plt.subplots(figsize=(8, 9), facecolor='#111')
    ax.imshow(frame, interpolation='nearest')
    ax.axis('off')
    title = (
        f"{render_hud_text(st, info)}  |  Step {step_num}  |  "
        f"Reward {total_eval_reward:.1f}"
    )
    ax.set_title(title, color='white', fontsize=11, pad=10)
    for i, line in enumerate(ghost_legend_lines()):
        fig.text(0.5, 0.02 - i * 0.025, line, ha='center', color='#ccc', fontsize=9)
    display(fig)
    plt.close(fig)
    time.sleep(0.06)

print('Game Over!')
# Out:
# Game Over!

# %% [markdown]
# # 03 – CNN Object Detector Training
#
# Train the convolutional network to map raw game frames to state vectors.

# %%
import sys
sys.path.insert(0, '..')
import torch
from src.models.cnn_detector import PacmanCNN, ObjectDetector
from src.environment.pacman_env import PacmanEnv, _OBS_SIZE

# %%
# Instantiate detector
detector = ObjectDetector(obs_size=_OBS_SIZE, device='cpu')
print('CNN parameters:', sum(p.numel() for p in detector.cnn.parameters()))

# %%
# Synthetic training loop placeholder
import numpy as np
env = PacmanEnv(seed=0)
obs, _ = env.reset()

# In a real scenario, frames would be captured from a screen grabber.
# Here we show the inference interface.
fake_frame = np.random.randint(0, 255, (84, 84, 3), dtype=np.uint8)
predicted_obs = detector.predict(fake_frame)
print('Predicted obs shape:', predicted_obs.shape)
